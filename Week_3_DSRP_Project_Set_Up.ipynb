# %% [markdown]
# <a href="https://colab.research.google.com/github/Blessing526/Med-School-Acceptances/blob/main/Week_3_DSRP_Project_Set_Up.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello World!")
#Possible research questions
#Is medical school becoming more or less competitive over time?

#Have GPA or MCAT expectations changed in the last 10–20 years?
# Out:
# Hello World!

# %%
import pandas as pd
from google.colab import files
import matplotlib.pyplot as plt

uploaded = files.upload()

# Load gender trends
df_scores = pd.read_excel('Table_A-16.xlsx', skiprows=4)
df_scores.head(31)
# Out:
#      <input type="file" id="files-3421b737-5c2a-4b7d-99ca-8829b5518566" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3421b737-5c2a-4b7d-99ca-8829b5518566">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df_scores.columns = ['MCAT/GPA','Mean/SD','2019','2020','2021','2022','2023','2024']
df_scores.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37 entries, 0 to 36
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   MCAT/GPA  20 non-null     object
#  1   Mean/SD   32 non-null     object
#  2   2019      35 non-null     object
#  3   2020      35 non-null     object
#  4   2021      35 non-null     object
#  5   2022      35 non-null     object
#  6   2023      35 non-null     object
#  7   2024      35 non-null     object
# dtypes: object(8)
# memory usage: 2.4+ KB

# %%
df_scores.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37 entries, 0 to 36
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   MCAT/GPA  20 non-null     object
#  1   Mean/SD   32 non-null     object
#  2   2019      35 non-null     object
#  3   2020      35 non-null     object
#  4   2021      35 non-null     object
#  5   2022      35 non-null     object
#  6   2023      35 non-null     object
#  7   2024      35 non-null     object
# dtypes: object(8)
# memory usage: 2.4+ KB

# %%
df_scores.include_index=False
df_scores.head()

#2019-2020 mean and sd in list form
twenty_nineteen = df_scores['2019']
twenty_nineteen_list = twenty_nineteen.tolist()
print(twenty_nineteen_list)

#2020-2021 mean and sd in list form
twenty_twenty = df_scores['2020']
twenty_twenty_list = twenty_twenty.tolist()
print(twenty_twenty_list)

#2021-2022 mean and sd in list form
twenty_twentyone = df_scores['2021']
twenty_twentyone_list = twenty_twentyone.tolist()
print(twenty_twentyone_list)

#2022-2023 mean and sd in list form
twenty_twentytwo = df_scores['2022']
twenty_twentytwo_list = twenty_twentytwo.tolist()
print(twenty_twentytwo_list)

#2023-2024 mean and sd in list form
twenty_twentythree = df_scores['2023']
twenty_twentythree_list = twenty_twentythree.tolist()
print(twenty_twentythree_list)

#2020-2021 mean and sd in list form
twenty_twentyfour = df_scores['2024']
twenty_twentyfour_list = twenty_twentyfour.tolist()
print(twenty_twentyfour_list)
# Out:
# [126.4, 2.8, 125.9, 2.7, 126.7, 2.7, 127.1, 2.7, 506.1, 9.3, 3.48, 0.43, 3.72, 0.28, 3.58, 0.33, 53369, nan, '2019-2020', 127.8, 2.2, 127.1, 2.3, 128.1, 2.1, 128.5, 2, 511.5, 6.5, 3.66, 0.3, 3.81, 0.22, 3.73, 0.24, 21869, nan]
# [126.5, 2.8, 125.9, 2.7, 126.8, 2.7, 127.2, 2.7, 506.4, 9.2, 3.49, 0.42, 3.74, 0.28, 3.6, 0.33, 53030, nan, '2020-2021', 127.8, 2.2, 127, 2.3, 128.1, 2, 128.6, 2, 511.5, 6.5, 3.66, 0.31, 3.82, 0.21, 3.73, 0.24, 22239, nan]
# [126.3, 2.9, 125.7, 2.8, 126.7, 2.8, 127.3, 2.8, 505.9, 9.7, 3.48, 0.44, 3.74, 0.28, 3.59, 0.34, 62443, nan, '2021-2022', 127.9, 2.2, 127, 2.3, 128.2, 2.1, 128.8, 2, 511.9, 6.6, 3.67, 0.31, 3.83, 0.21, 3.74, 0.25, 22666, nan]
# [126.4, 2.9, 125.8, 2.8, 126.8, 2.9, 127.5, 2.8, 506.5, 9.9, 3.52, 0.42, 3.76, 0.28, 3.62, 0.33, 55189, nan, '2022-2023', 127.9, 2.2, 127, 2.4, 128.2, 2.1, 128.9, 2, 511.9, 6.7, 3.68, 0.31, 3.84, 0.21, 3.75, 0.24, 22710, nan]
# ...

# %%
df_scores.isnull().sum()
# Out:
# MCAT/GPA    17
# Mean/SD      5
# 2019         2
# 2020         2
# 2021         2
# 2022         2
# 2023         2
# 2024         2
# dtype: int64

# %%
df_scores.columns
# Out:
# Index(['MCAT/GPA', 'Mean/SD', '2019', '2020', '2021', '2022', '2023', '2024'], dtype='object')

# %%
df_scores.shape
# Out:
# (37, 8)

# %% [markdown]
# # **My main data set and analysis of it.**

# %%
import numpy as np

# Create a larger dataset with some messy data
n_rows = 100
data = {
    'Group': ['Applicants','Applicants','Applicants','Applicants','Applicants','Applicants','Applicants','Applicants','Applicants','Applicants','Applicants','Applicants','Applicants','Applicants','Applicants','Applicants','Applicants',
              'Matriculants','Matriculants','Matriculants','Matriculants','Matriculants','Matriculants','Matriculants','Matriculants','Matriculants','Matriculants','Matriculants','Matriculants','Matriculants','Matriculants','Matriculants','Matriculants','Matriculants',],
    'Metric': ['MCAT CPBS','MCAT CPBS','MCAT CARS','MCAT CARS','MCAT BBLS','MCAT BBLS','MCAT PSBB','MCAT PSBB','Total MCAT','Total MCAT','GPA Science','GPA Science','GPA Non-Science','GPA Non-Science','GPA Total','GPA Total','Total Applicants',
               'MCAT CPBS','MCAT CPBS','MCAT CARS','MCAT CARS','MCAT BBLS','MCAT BBLS','MCAT PSBB','MCAT PSBB','Total MCAT','Total MCAT','GPA Science','GPA Science','GPA Non-Science','GPA Non-Science','GPA Total','GPA Total','Total Matriculants'],
    'Stat': ['Mean', 'SD', 'Mean', 'SD', 'Mean', 'SD','Mean', 'SD','Mean', 'SD','Mean', 'SD','Mean', 'SD','Mean', 'SD','Total',
             'Mean', 'SD', 'Mean', 'SD', 'Mean', 'SD','Mean', 'SD','Mean', 'SD','Mean', 'SD','Mean', 'SD','Mean', 'SD','Total'],  #Mean or Standard deviation(SD)
    '2019-2020': [126.4, 2.8, 125.9, 2.7, 126.7, 2.7, 127.1, 2.7, 506.1, 9.3, 3.48, 0.43, 3.72, 0.28, 3.58, 0.33, 53369, 127.8, 2.2, 127.1, 2.3, 128.1, 2.1, 128.5, 2.0, 511.5, 6.5, 3.66, 0.3, 3.81, 0.22, 3.73, 0.24, 21869],  # Score Data from 2019-2020
    '2020-2021': [126.5, 2.8, 125.9, 2.7, 126.8, 2.7, 127.2, 2.7, 506.4, 9.2, 3.49, 0.42, 3.74, 0.28, 3.6, 0.33, 53030, 127.8, 2.2, 127, 2.3, 128.1, 2.0, 128.6, 2.0, 511.5, 6.5, 3.66, 0.31, 3.82, 0.21, 3.73, 0.24, 22239],  # Score Data from 2020-2021
    '2021-2022': [126.3, 2.9, 125.7, 2.8, 126.7, 2.8, 127.3, 2.8, 505.9, 9.7, 3.48, 0.44, 3.74, 0.28, 3.59, 0.34, 62443, 127.9, 2.2, 127, 2.3, 128.2, 2.1, 128.8, 2.0, 511.9, 6.6, 3.67, 0.31, 3.83, 0.21, 3.74, 0.25, 22666],  # Score Data from 2021-2022
    '2022-2023': [126.4, 2.9, 125.8, 2.8, 126.8, 2.9, 127.5, 2.8, 506.5, 9.9, 3.52, 0.42, 3.76, 0.28, 3.62, 0.33, 55189, 127.9, 2.2, 127, 2.4, 128.2, 2.1, 128.9, 2.0, 511.9, 6.7, 3.68, 0.31, 3.84, 0.21, 3.75, 0.24, 22710],  # Score Data from 2022-2023
    '2023-2024': [126.4, 3.0, 125.8, 2.8, 126.6, 2.9, 127.4, 2.8, 506.3, 10.0, 3.54, 0.42, 3.78, 0.27, 3.64, 0.33, 52577, 127.8, 2.3, 127, 2.4, 128.1, 2.1, 128.9, 2.0, 511.7, 6.9, 3.71, 0.3, 3.85, 0.2, 3.77, 0.23, 22980],  # Score Data from 2023-2024
    '2024-2025': [126.3, 3, 125.8, 2.8, 126.6, 2.9, 127.4, 2.8, 506.1, 10.1, 3.56, 0.42, 3.79, 0.27, 3.66, 0.33, 51946, 127.9, 2.3, 126.9, 2.3, 128.1, 2.1, 128.9, 2.0, 511.8, 6.7, 3.73, 0.29, 3.87, 0.19, 3.79, 0.23, 23156],  # Score Data from 2024-2025
}

# Create DataFrame
score_df = pd.DataFrame(data)
score_df.head(35)
# Out:
#            Group              Metric   Stat  2019-2020  2020-2021  2021-2022  \
# 0     Applicants           MCAT CPBS   Mean     126.40     126.50     126.30
# 1     Applicants           MCAT CPBS     SD       2.80       2.80       2.90
# 2     Applicants           MCAT CARS   Mean     125.90     125.90     125.70
# 3     Applicants           MCAT CARS     SD       2.70       2.70       2.80
# 4     Applicants           MCAT BBLS   Mean     126.70     126.80     126.70
# 5     Applicants           MCAT BBLS     SD       2.70       2.70       2.80
# 6     Applicants           MCAT PSBB   Mean     127.10     127.20     127.30
# 7     Applicants           MCAT PSBB     SD       2.70       2.70       2.80
# 8     Applicants          Total MCAT   Mean     506.10     506.40     505.90
# 9     Applicants          Total MCAT     SD       9.30       9.20       9.70
# 10    Applicants         GPA Science   Mean       3.48       3.49       3.48
# ...

# %%
score_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34 entries, 0 to 33
# Data columns (total 9 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Group      34 non-null     object
#  1   Metric     34 non-null     object
#  2   Stat       34 non-null     object
#  3   2019-2020  34 non-null     float64
#  4   2020-2021  34 non-null     float64
#  5   2021-2022  34 non-null     float64
#  6   2022-2023  34 non-null     float64
#  7   2023-2024  34 non-null     float64
#  8   2024-2025  34 non-null     float64
# dtypes: float64(6), object(3)
# memory usage: 2.5+ KB

# %%
score_df.shape
# Out:
# (34, 9)

# %%
score_df.describe()
# Out:
#           2019-2020     2020-2021     2021-2022     2022-2023     2023-2024  \
# count     34.000000     34.000000     34.000000     34.000000     34.000000
# mean    2274.478824   2275.403824   2564.846471   2352.840000   2283.948235
# std     9772.038280   9741.146943  11267.890423  10111.498481   9716.763198
# min        0.220000      0.210000      0.210000      0.210000      0.200000
# 25%        2.225000      2.225000      2.225000      2.250000      2.325000
# 50%        3.690000      3.695000      3.705000      3.715000      3.740000
# 75%      127.000000    126.950000    126.925000    126.950000    126.900000
# max    53369.000000  53030.000000  62443.000000  55189.000000  52577.000000
#
#           2024-2025
# count     34.000000
# mean    2270.556765
# std     9629.422371
# min        0.190000
# 25%        2.300000
# 50%        3.760000
# 75%      126.825000
# max    51946.000000

# %% [markdown]
# ## **Visualizations**

# %%
# Extract total applicants and matriculants
# Why?... To see how the number of applicants compares with matriculants each year.
applicants = score_df[score_df['Metric'] == 'Total Applicants'].iloc[0, 3:]
matriculants = score_df[score_df['Metric'] == 'Total Matriculants'].iloc[0, 3:]

plt.figure(figsize=(10, 6))
plt.plot(applicants.index, applicants.values, label='Total Applicants', marker='o')
plt.plot(matriculants.index, matriculants.values, label='Total Matriculants', marker='o')
plt.xticks(rotation=45)
plt.title("Applicants vs Matriculants Over Time")
plt.ylabel("Number of People")
plt.legend()
plt.tight_layout()
plt.show()

# %%
# Filter for Matriculants, Total MCAT Mean, and GPA Total Mean
matriculants_df = score_df[(score_df['Group'] == 'Matriculants') &
                           (score_df['Stat'] == 'Mean') &
                           (score_df['Metric'].isin(['Total MCAT', 'GPA Total']))]

# Set 'Metric' as index
matriculants_df = matriculants_df.set_index('Metric')

# Extract values for plotting
years = ['2019-2020','2020-2021','2021-2022','2022-2023','2023-2024','2024-2025']
mcat_means = matriculants_df.loc['Total MCAT', years]
gpa_means = matriculants_df.loc['GPA Total', years]

# %%
# Filter for total GPA mean rows only
gpa_df = score_df[
    (score_df['Metric'] == 'GPA Total') &
    (score_df['Stat'] == 'Mean')
]

# Set the index to Group for easier plotting
gpa_df = gpa_df.set_index('Group')

# Select the relevant years
years = ['2019-2020', '2020-2021', '2021-2022', '2022-2023', '2023-2024', '2024-2025']

x_points = np.arange(len(years))

# Plotting
fig, ax = plt.subplots(figsize=(10, 6))

# Bar plots for Applicants and Matriculants
ax.bar(
    [i - 0.35/2 for i in x_points],
    gpa_df.loc['Applicants', years],
    0.35,
    label='Applicants',
    color='skyblue'
)
ax.bar(
    [i + 0.35/2 for i in x_points],
    gpa_df.loc['Matriculants', years],
    0.35,
    label='Matriculants',
    color='lightgreen'
)

ax.set_title('Total GPA Mean: Applicants vs. Matriculants (2019–2025)')
ax.set_xlabel('Application Year')
ax.set_ylabel('GPA Mean')
ax.set_xticks(x_points)
ax.set_xticklabels(years, rotation=45)
ax.legend()
ax.grid(True, linestyle='--', alpha=0.5)

plt.tight_layout()
plt.show()

#comparing the GPA Total Mean of applicants vs. matriculants side by side.

# %% [markdown]
# # **Extra Stuff I May Not Need But Will Reference**

# %%
# Filter for Total MCAT Mean and SD for Applicants
total_mcat = score_df[(score_df['Metric'] == 'Total MCAT')]

# Create simulated data for each year
years = ['2019-2020', '2020-2021', '2021-2022', '2022-2023', '2023-2024', '2024-2025']
plt.figure(figsize=(10, 6))

np.random.seed(42)  # For reproducibility

for year in years:
    mean = total_mcat[total_mcat['Stat'] == 'Mean'][year].values[0]
    sd = total_mcat[total_mcat['Stat'] == 'SD'][year].values[0]

    # Simulate 1000 samples from normal distribution
    samples = np.random.normal(mean, sd, 1000)

    plt.hist(samples, bins=30, alpha=0.5, label=year)

plt.title("Overlaying Histogram of Total MCAT Scores (Applicants)")
plt.xlabel("MCAT Score")
plt.ylabel("Frequency")
plt.legend()
plt.grid(True)
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# We assume score_df is already created as in your code above

# Filter for GPA Total Mean and SD for Applicants
gpa_total = score_df[(score_df['Metric'] == 'GPA Total')]

# Years to visualize
years = ['2019-2020', '2020-2021', '2021-2022', '2022-2023', '2023-2024', '2024-2025']

plt.figure(figsize=(10, 6))
np.random.seed(42)  # For reproducibility

for year in years:
    mean = gpa_total[gpa_total['Stat'] == 'Mean'][year].values[0]
    sd = gpa_total[gpa_total['Stat'] == 'SD'][year].values[0]

    # Simulate GPA samples (1000 samples per year)
    samples = np.random.normal(mean, sd, 1000)

    plt.hist(samples, bins=30, alpha=0.5, label=year)

plt.title("Overlaying Histogram of Total GPA (Applicants)")
plt.xlabel("GPA")
plt.ylabel("Frequency")
plt.legend()
plt.grid(True)
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Assuming score_df is already defined as before

# Years to visualize
years = ['2019-2020', '2020-2021', '2021-2022', '2022-2023', '2023-2024', '2024-2025']
np.random.seed(42)  # For reproducibility

# Filter Total MCAT and GPA Total data
total_mcat = score_df[score_df['Metric'] == 'Total MCAT']
gpa_total = score_df[score_df['Metric'] == 'GPA Total']

# Create figure with 2 subplots
fig, axes = plt.subplots(1, 2, figsize=(16, 6))

# ------------------ MCAT Histogram ------------------
for year in years:
    mean = total_mcat[total_mcat['Stat'] == 'Mean'][year].values[0]
    sd = total_mcat[total_mcat['Stat'] == 'SD'][year].values[0]
    samples = np.random.normal(mean, sd, 1000)
    axes[0].hist(samples, bins=30, alpha=0.5, label=year)

axes[0].set_title("Total MCAT Scores (Applicants)")
axes[0].set_xlabel("MCAT Score")
axes[0].set_ylabel("Frequency")
axes[0].legend()
axes[0].grid(True)

# ------------------ GPA Histogram ------------------
for year in years:
    mean = gpa_total[gpa_total['Stat'] == 'Mean'][year].values[0]
    sd = gpa_total[gpa_total['Stat'] == 'SD'][year].values[0]
    samples = np.random.normal(mean, sd, 1000)
    axes[1].hist(samples, bins=30, alpha=0.5, label=year)

axes[1].set_title("Total GPA (Applicants)")
axes[1].set_xlabel("GPA")
axes[1].set_ylabel("Frequency")
axes[1].legend()
axes[1].grid(True)

# Adjust layout
plt.tight_layout()
plt.show()
